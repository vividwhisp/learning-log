# %%
from transformers import pipeline

classifier = pipeline("sentiment-analysis")

classifier(
    [
        "I've been waiting for a HuggingFace course my whole life.",
        "I love this so much!",
    ]
)
# Out:
# [transformers] No model was supplied, defaulted to distilbert/distilbert-base-uncased-finetuned-sst-2-english and revision 714eb0f.
# Using a pipeline without specifying a model name and revision in production is not recommended.
# Loading weights: 100%|██████████| 104/104 [00:00<00:00, 4239.68it/s]
# [{'label': 'POSITIVE', 'score': 0.9598049521446228},
#  {'label': 'POSITIVE', 'score': 0.9998788833618164}]

# %%
classifier(
    "This is a course about the Transformers library"
)
# Out:
# [{'label': 'POSITIVE', 'score': 0.9925565123558044}]

# %%
sent = "fuck you"
classifier(
    sent
)
# Out:
# [{'label': 'NEGATIVE', 'score': 0.9923542737960815}]

# %%
from transformers import pipeline

generator = pipeline("text-generation", model="HuggingFaceTB/SmolLM2-360M")
resp = generator(
    "In this course, we will teach you how to",
    max_length=30,
    num_return_sequences=2,
)
print(resp)
# Out:
# Loading weights: 100%|██████████| 290/290 [00:00<00:00, 2578.27it/s]
# [transformers] Both `max_new_tokens` (=256) and `max_length`(=30) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [{'generated_text': 'In this course, we will teach you how to use the tools of Python to create a custom data analysis package. We will walk you through the process of building and testing your own custom data analysis package, and we will make sure to use code examples to help you along the way.\n\nWe will also make sure to explain the concepts and code in detail, so that you can understand and appreciate them fully. We will also cover the basics of programming in Python, so that you can get started right away.\n\nThis course will be designed to be completely free of charge, so you will be able to start using your new custom data analysis package as soon as you download it.\n\nIf you are interested in learning more about Python and data analysis, we suggest that you take the plunge and sign up for this course. It is the perfect way to start your journey towards becoming a data analyst!\n\n## 6. Python in the Workplace: The Use of Python in the Workplace\n\nPython is a powerful and widely used programming language that has found its way into many different industries. As a result, Python has also found its way into many industries, including the workplace.\n\nIn this course, we will explore the use of Python in the workplace, including how it can be used in the development of'}, {'generated_text': "In this course, we will teach you how to be an amazing writer. But, before we start, let me first tell you why learning to write well is so important.\n\nHave you ever wanted to share your thoughts, feelings, or ideas with others? Maybe you want to write a story about your favorite book, a poem about your pet, or even a letter to your pen pal. Whatever your reason may be, being able to express yourself clearly and effectively is an essential skill that can help you succeed in school, at home, and in life.\n\nSo, how do we become great writers? One way is by practicing our skills regularly. Just like athletes need to practice their sports to get better, writers need to practice their writing to become better at it. And one way to practice is by reading and analyzing other people's works. This can help us understand what makes a piece of writing effective and identify areas where we can improve.\n\nNow, let's talk about some specific things that we will be learning in this course. First, we will explore different genres of writing, such as novels, poetry, essays, and articles. Each genre has its own unique features and conventions, so it's important to understand them before we dive into writing. For example, when writing a novel, you will"}]

# %%
generator("my name is", max_length=6)
# Out:
# [transformers] Passing `generation_config` together with generation-related arguments=({'max_length'}) is deprecated and will be removed in future versions. Please pass either a `generation_config` object OR all generation parameters explicitly, but not both.
# [transformers] Both `max_new_tokens` (=256) and `max_length`(=6) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [{'generated_text': 'my name is A and I am a big fan of your site.\n\nI would like to know if you have a list of the most frequent words that are used in your website.\n\nI can\'t find it on the site, but I would love to know.\n\nThanks in advance for the help.\n\nThanks,\n\nIan\n\nHi Ian,\n\nI don\'t have a list of the most frequent words but would like to think I do...\n\nI just created a list of all the words that appear in the following categories:\n\n<a href="http://www.google.com">google</a>\n<a href="http://www.facebook.com">facebook</a>\n<a href="http://www.yahoo.com">yahoo</a>\n<a href="http://www.linkedin.com">linkedin</a>\n<a href="http://www.amazon.com">amazon</a>\n<a href="http://www.google.co.uk">google.co.uk</a>\n\n<a href="http://www.youtube.com">youtube</a>\n<a href="http://www.google.'}]
